# %%
import pandas as pd

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Dell'

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\Dell\Downloads\archive\1_dirty_data.csv")
df
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 901         622          623         1       3
# 902          77           78         0       3
# 903         715          716         0       3
# 904         623          624         0       3
# 905         888          889         0       3
#
#                                                   Name     Sex   Age SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0     1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0     1
# 2                               Heikkinen, Miss. Laina  female  26.0     0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0     1
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0       0
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            183
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          699
# Embarked         2
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(15)

# %%
df.duplicated().sum()
# Out:
# np.int64(15)

# %%
df.dtypes
# Out:
# Unnamed: 0       int64
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp           object
# Parch            int64
# Ticket          object
# Fare            object
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 906 entries, 0 to 905
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   906 non-null    int64
#  1   PassengerId  906 non-null    int64
#  2   Survived     906 non-null    int64
#  3   Pclass       906 non-null    int64
#  4   Name         906 non-null    object
#  5   Sex          906 non-null    object
#  6   Age          723 non-null    float64
#  7   SibSp        906 non-null    object
#  8   Parch        906 non-null    int64
#  9   Ticket       906 non-null    object
#  10  Fare         906 non-null    object
#  11  Cabin        207 non-null    object
#  12  Embarked     904 non-null    object
# dtypes: float64(1), int64(5), object(7)
# memory usage: 92.1+ KB

# %%
df.describe()
# Out:
#        Unnamed: 0  PassengerId    Survived      Pclass         Age       Parch
# count  906.000000   906.000000  906.000000  906.000000  723.000000  906.000000
# mean   447.181015   448.181015    0.384106    2.311258   29.684882    0.379691
# std    257.105293   257.105293    0.486652    0.837139   14.474664    0.802886
# min      0.000000     1.000000    0.000000    1.000000    0.420000    0.000000
# 25%    225.250000   226.250000    0.000000    2.000000   20.000000    0.000000
# 50%    448.500000   449.500000    0.000000    3.000000   28.000000    0.000000
# 75%    668.750000   669.750000    1.000000    3.000000   38.000000    0.000000
# max    890.000000   891.000000    1.000000    3.000000   80.000000    6.000000

# %%
df.isnull().sum()
# Out:
# Unnamed: 0     0
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
df=df.drop_duplicates()
df
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name     Sex   Age SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0     1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0     1
# 2                               Heikkinen, Miss. Laina  female  26.0     0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0     1
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df=df.replace('male','Male')

df
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name     Sex   Age SibSp  \
# 0                              Braund, Mr. Owen Harris    Male  22.0     1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  FeMale  38.0     1
# 2                               Heikkinen, Miss. Laina  FeMale  26.0     0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  FeMale  35.0     1
# ...

# %%
df=df.replace('FeMale','female')

# %%
df
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name     Sex   Age SibSp  \
# 0                              Braund, Mr. Owen Harris    Male  22.0     1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0     1
# 2                               Heikkinen, Miss. Laina  female  26.0     0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0     1
# ...

# %%
df["Sex"].unique()
# Out:
# array(['Male', 'female', 'F'], dtype=object)

# %%
df=df.replace('F','female')

# %%
df["Sex"].unique()
# Out:
# array(['Male', 'female'], dtype=object)

# %%
df["Embarked"].unique()
# Out:
# array(['S', 'C', 'Q', 'Queenstown'], dtype=object)

# %%
df=df.replace('Queenstown','Q')

# %%
df["Embarked"].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Unnamed: 0  PassengerId    Survived      Pclass         Age       Parch
# count  891.000000   891.000000  891.000000  891.000000  891.000000  891.000000
# mean   445.000000   446.000000    0.383838    2.308642   29.361582    0.381594
# std    257.353842   257.353842    0.486592    0.836071   13.019697    0.806057
# min      0.000000     1.000000    0.000000    1.000000    0.420000    0.000000
# 25%    222.500000   223.500000    0.000000    2.000000   22.000000    0.000000
# 50%    445.000000   446.000000    0.000000    3.000000   28.000000    0.000000
# 75%    667.500000   668.500000    1.000000    3.000000   35.000000    0.000000
# max    890.000000   891.000000    1.000000    3.000000   80.000000    6.000000

# %%
Q1=df["Age"].quantile(0.25)
Q3=df["Age"].quantile(0.75)
IQR=Q3-Q1
lower=Q1-1.5*IQR
Upper=Q3+1.5*IQR
outliers=df[(df["Age"]<lower) | (df["Age"]>upper)]
print("Lower Limit:", lower)
print("Upper Limit:", Upper)
print("Number of Outliers")
len(outliers)
# Out:
# Lower Limit: 2.5
# Upper Limit: 54.5
# Number of Outliers
# 66

# %%
outliers.head()
# Out:
#     Unnamed: 0  PassengerId  Survived  Pclass  \
# 7            7            8         0       3
# 11          11           12         1       1
# 15          15           16         1       2
# 16          16           17         0       3
# 33          33           34         0       2
#
#                                 Name     Sex   Age SibSp  Parch      Ticket  \
# 7     Palsson, Master. Gosta Leonard    Male   2.0     3      1      349909
# 11          Bonnell, Miss. Elizabeth  female  58.0     0      0      113783
# 15  Hewlett, Mrs. (Mary D Kingcome)   female  55.0     0      0      248706
# 16              Rice, Master. Eugene    Male   2.0     4      1      382652
# 33             Wheadon, Mr. Edward H    Male  66.0     0      0  C.A. 24579
#
#       Fare Embarked
# 7   $21.08        S
# 11  $26.55        S
# 15  $16.00        S
# 16  $29.13        Q
# 33  $10.50        S

# %%
df["Fare"]=df["Fare"].str.replace("$","",regex=False)
df["Fare"]=pd.to_numeric(df["Fare"])

# %%
Q1 = df["Fare"].quantile(0.25)
Q3 = df["Fare"].quantile(0.75)
IQR = Q3-Q1
lower=Q1-1.5*IQR
Upper=Q3+1.5*IQR
outliers=df[(df["Fare"]<lower) | (df["Fare"]>upper)]
print("Lower Limit:", lower)
print("Upper Limit:", Upper)
print("Number of Outliers")
len(outliers)
# Out:
# Lower Limit: -26.7125
# Upper Limit: 65.6275
# Number of Outliers
# 141

# %%
df.dtypes
# Out:
# Unnamed: 0       int64
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp           object
# Parch            int64
# Ticket          object
# Fare           float64
# Embarked        object
# dtype: object

# %%
df[df["SibSp"]=="one"]
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 98           98           99         1       2
# 104         104          105         0       3
# 499         499          500         0       3
#
#                                      Name     Sex   Age SibSp  Parch   Ticket  \
# 98   Doling, Mrs. John T (Ada Julia Bone)  female  34.0   one      1   231919
# 104        Gustafsson, Mr. Anders Vilhelm    Male  37.0   one      0  3101276
# 499                    Svensson, Mr. Olof    Male  24.0   one      0   350035
#
#       Fare Embarked
# 98   23.00        S
# 104   7.93        S
# 499   7.80        S

# %%
df["SibSp"]=df["SibSp"].replace("one",1)

# %%
df["SibSp"].unique()
# Out:
# array([1, 0, 3, 4, 2, 5, 8])

# %%
df["SibSp"]=df["SibSp"].astype(int)

# %%
df["SibSp"].dtype
# Out:
# dtype('int64')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
print(df.columns.tolist())
# Out:
# ['Unnamed: 0', 'PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Embarked']

# %%
df.columns=df.columns.str.strip()

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df.to_csv(r"C:\Users\Dell\OneDrive\Documents\internship projects\cleaned_titanic.csv",index=False)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    Male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    Male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)
